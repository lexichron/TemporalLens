# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import torch
from tqdm import tqdm
from OmniEvent.infer import infer, AttrDict, get_model, get_tokenizer

MODEL_PATH = "../models/s2s-mt5-ed/"
torch.cuda.is_available = lambda: False
torch.cuda.device_count = lambda: 0

# %%
device = torch.device("cpu")
if torch.cuda.is_available():
    device = 'cuda'

def get_model_and_tokenizer(model_name_or_path):
    
    model_args = AttrDict({
        "paradigm": "seq2seq",
        "model_type": "mt5"
    })
    model = get_model(model_args, model_name_or_path)
    model = model.to(device)
    # tokenizer 
    tokenizer = get_tokenizer(model_name_or_path)

    return model, tokenizer

# %%
df = pd.read_csv("../data/data.csv")
#df = df.sample(n=50, random_state=42)

# %%
model, tokenizer = get_model_and_tokenizer(MODEL_PATH)
# Out:
# load from local file: ../models/s2s-mt5-ed/ model
# load from local file: ../models/s2s-mt5-ed/ tokenizer

# %%
# from title
ed_results = []
for row in df.itertuples(index=False):
    res = infer(text=row.Title, task="ED", model=model, tokenizer=tokenizer)
    ed_results.append(res)
# Out:
# [{'text': 'Fed officials warn of inflation risks from tariff surge', 'events': []}]
# [{'text': 'While You Were Sleeping: 5 stories you might have missed, Feb 4, 2025', 'events': []}]
# [{'text': "Slower growth, souring business sentiment: How Trump's tariffs could hurt Singapore's economy", 'events': []}]
# [{'text': "Malaysia's ECRL: A closer look at the US$11.2b railway’s promises of boosting jobs for locals and making money", 'events': []}]
# [{'text': 'S&P 500, Nasdaq, pare losses as Trump’s Mexico tariffs paused', 'events': []}]
# [{'text': 'Democrats blast Musk as USAID agency HQ shutters', 'events': [{'type': 'attack', 'trigger': 'blast', 'offset': [10, 15]}]}]
# [{'text': "Trump to speak with China's Xi after raising tariffs, White House says", 'events': [{'type': 'meet', 'trigger': 'speak', 'offset': [9, 14]}]}]
# [{'text': '‘Good opportunity’ for Rubio, Wang to meet at UN on Feb 18, says China’s UN envoy', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [38, 42]}]}]
# [{'text': 'Explainer: What is USAID and why has it become a target for Trump and Musk?', 'events': []}]
# [{'text': 'Explainer-What is USAID and why has it become a target for Trump and Musk?', 'events': []}]
# [{'text': "Rubio hails Panama's move to exit Chinese infrastructure plan", 'events': []}]
# [{'text': 'Trump wants Ukraine to guarantee US access to rare earths in return for war aid', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [72, 75]}]}]
# [{'text': 'From flash drives to world-first AI security: Home-grown firm’s success puts S’pore on global tech map', 'events': []}]
# [{'text': 'Trump trade threats overshadow European defence meet', 'events': []}]
# [{'text': '‘Great step forward’: Rubio hails Panama’s move to exit China’s Belt and Road Initiative', 'events': []}]
# [{'text': 'US tariffs on Mexico to be paused for a month, Trump says', 'events': []}]
# [{'text': 'Mexico and Canada say Trump will pause tariffs for one month', 'events': []}]
# [{'text': 'US tariffs on Mexico to be paused for a month, says Trump', 'events': []}]
# [{'text': 'Stock markets sink, dollar rallies on Trump tariffs', 'events': []}]
# [{'text': 'White House says Canada has ‘misunderstood’ Trump’s tariff order, Mexico is ‘serious’', 'events': []}]
# [{'text': 'Locals struggle at Singapore Smash as veterans steal limelight', 'events': []}]
# [{'text': "China to file lawsuit at WTO over Trump's trade tariffs", 'events': [{'type': 'sue', 'trigger': 'lawsuit', 'offset': [14, 21]}]}]
# [{'text': "Trump says will 'definitely' impose tariffs on EU as bloc gathers for 'triple first' meeting", 'events': [{'type': 'meet', 'trigger': 'meeting', 'offset': [85, 92]}]}]
# [{'text': 'Trump tariffs on Canada, Mexico and China rattle markets', 'events': []}]
# [{'text': 'Factories in Singapore and across Asia bracing themselves for impact from Trump’s tariffs', 'events': [{'type': 'transfermoney', 'trigger': 'tariffs', 'offset': [82, 89]}]}]
# [{'text': 'Thailand Masters badminton champion Jason Teh gets warm welcome home', 'events': []}]
# [{'text': 'Singapore shares track regional declines as Trump’s tariffs rattle investors; STI down 0.8%', 'events': []}]
# [{'text': 'European leaders warn of pain from transatlantic trade war', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [17, 20]}]}]
# [{'text': 'Evening Update: Today’s headlines from The Straits Times on Feb 3, 2025', 'events': []}]
# [{'text': "Higher prices, supply chain disruptions: Trump's tariff war could ‘end very badly’, say analysts", 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [56, 59]}]}]
# [{'text': '‘Shancai forever’: Taiwanese celebrities mourn death of actress Barbie Hsu', 'events': [{'type': 'die', 'trigger': 'death', 'offset': [47, 52]}]}]
# [{'text': 'Trump’s revival of trade wars brings spotlight on Shein', 'events': [{'type': 'attack', 'trigger': 'wars', 'offset': [25, 29]}]}]
# [{'text': 'Canada, China, Mexico, and the art of retaliation', 'events': []}]
# [{'text': "Hong Kong's economic growth slows to 2.5% in 2024", 'events': []}]
# [{'text': "Trump, asked on UK tariffs, says 'I think that one can be worked out'", 'events': []}]
# [{'text': "EU must stay united in face of Trump's tariff threat, Spanish minister says", 'events': []}]
# [{'text': 'Singapore seen taking indirect hit from Trump’s tariffs on China, Canada and Mexico', 'events': [{'type': 'attack', 'trigger': 'hit', 'offset': [31, 34]}]}]
# [{'text': 'How China allegedly contributes to the deadly fentanyl crisis', 'events': []}]
# [{'text': "China to propose restoring 2020 'Phase 1' trade deal with US, WSJ reports", 'events': []}]
# [{'text': "Trump says Americans may feel 'pain' in trade war with Mexico, Canada, China", 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [46, 49]}]}]
# [{'text': 'Taiwan to help companies relocate to US following Trump tariffs', 'events': [{'type': 'transport', 'trigger': 'relocate', 'offset': [25, 33]}]}]
# [{'text': 'Taiwan to help companies relocate to US following Trump tariffs', 'events': [{'type': 'transport', 'trigger': 'relocate', 'offset': [25, 33]}]}]
# [{'text': "Trump says Americans may feel 'pain' in trade war with Mexico, Canada, China", 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [46, 49]}]}]
# [{'text': "Taiwan and China need peace given 'multifold changes' internationally, president says", 'events': []}]
# [{'text': 'Here are the winners and losers in Asia from Trump’s tariffs', 'events': []}]
# [{'text': 'Russia and Trump push Europe to be more independent, Macron says', 'events': []}]
# [{'text': 'India vows to avoid protectionist signals on trade', 'events': []}]
# [{'text': "Taiwan and China need peace given 'multifold changes' internationally, president Lai says", 'events': []}]
# [{'text': 'Trump’s trade war: There will be pain. Can he make Americans grin and bear it?', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [14, 17]}]}]
# [{'text': "Asia's factory activity weakens as Trump tariffs jolt sentiment", 'events': []}]
# [{'text': 'China factory activity growth slows in January, Caixin PMI shows', 'events': []}]
# [{'text': 'Campari Group opens operating company in Singapore to capture thirsty Apac market', 'events': [{'type': 'startorg', 'trigger': 'opens', 'offset': [14, 19]}]}]
# [{'text': 'Factory activity slowed across Asia before Trump’s trade war kicked off', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [57, 60]}]}]
# [{'text': 'Trump announces talks with Canada, Mexico over sweeping tariffs', 'events': [{'type': 'meet', 'trigger': 'talks', 'offset': [16, 21]}]}]
# [{'text': 'Asian stocks dive as Trump tariffs trigger trade war fears', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [49, 52]}]}]
# [{'text': 'Tokyo, Seoul stocks drop on US tariffs', 'events': []}]
# [{'text': 'Taiwan says South Africa gives March deadline to move liaison office from Pretoria', 'events': [{'type': 'transport', 'trigger': 'move', 'offset': [49, 53]}]}]
# [{'text': 'Taiwan says South Africa gives March deadline to move office from Pretoria', 'events': [{'type': 'endposition', 'trigger': 'move', 'offset': [49, 53]}]}]
# [{'text': 'Taiwan says S.Africa gives March deadline to move office from Pretoria', 'events': [{'type': 'endposition', 'trigger': 'move', 'offset': [45, 49]}]}]
# [{'text': 'Bitcoin slides below US$100,000 as Trump tariffs rattle markets', 'events': []}]
# [{'text': 'US dollar surges, oil jumps as Asian stocks start to fall on Trump tariffs', 'events': []}]
# [{'text': 'Morning Briefing: Top stories from The Straits Times on Feb 3, 2025', 'events': []}]
# [{'text': "Rubio tells Panama to end China's influence of canal or face US action", 'events': []}]
# [{'text': 'Car prices face $4,000 increase as Trump tariffs hit auto sector', 'events': []}]
# [{'text': "Mexico's Sheinbaum vows resilience as US tariffs trigger trade war", 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [63, 66]}]}]
# [{'text': 'While You Were Sleeping: 5 stories you might have missed, Feb 3, 2025', 'events': []}]
# [{'text': 'Canada to take legal action against US for tariffs', 'events': []}]
# [{'text': "Malaysia's ECRL: Train service could breathe new life into drab port cities of Klang and Kuantan", 'events': []}]
# [{'text': 'Commentary: Xiaohongshu success with ‘TikTok refugees’ is testing China’s Great Firewall', 'events': []}]
# [{'text': 'US official pressures Panama over Chinese businesses near the canal', 'events': []}]
# [{'text': "Rubio tells Panama to end China's influence of canal or face US action", 'events': []}]
# [{'text': 'Trump 2.0: Policy disruption unleashed', 'events': []}]
# [{'text': 'Mexico vows retaliation to Trump tariffs without detailing targets', 'events': []}]
# [{'text': 'Tariff hikes unnerve Wall Street as US trade war seen jolting global markets', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [45, 48]}]}]
# [{'text': 'Trump tariff hikes unnerve Wall Street as trade war seen jolting global markets', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [48, 51]}]}]
# [{'text': "Trump says tariff 'pain' will be 'worth the price'", 'events': []}]
# [{'text': 'Rubio meets Panama leader on Trump demands for canal', 'events': [{'type': 'meet', 'trigger': 'meets', 'offset': [6, 11]}]}]
# [{'text': "EU slams Trump tariffs, says will 'respond firmly' if targeted", 'events': []}]
# [{'text': "EU slams Trump tariffs, says it will 'respond firmly' if targeted", 'events': []}]
# [{'text': 'Trump says ‘pain’ from tariffs will be ‘worth the price’', 'events': []}]
# [{'text': 'Beijing keeps door open for talks with Washington in measured response to tariff hike', 'events': [{'type': 'meet', 'trigger': 'talks', 'offset': [28, 33]}]}]
# [{'text': 'USAid website goes dark with future of US assistance in doubt', 'events': []}]
# [{'text': 'Evening Update: Today’s headlines from The Straits Times on Feb 2, 2025', 'events': []}]
# [{'text': 'North American companies brace themselves for fallout from Trump tariffs', 'events': []}]
# [{'text': "China denounces Trump tariff: 'Fentanyl is America's problem'", 'events': []}]
# [{'text': 'US President Trump signs order imposing fresh levies on Canada, Mexico and China', 'events': []}]
# [{'text': 'China shrugs off new Trump tariffs but bruising trade war looms', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [54, 57]}]}]
# [{'text': "Volkswagen sues India to quash 'enormous' $1.9 billion tax demand, legal filing shows", 'events': [{'type': 'sue', 'trigger': 'sues', 'offset': [11, 15]}]}]
# [{'text': 'Billionaire Ambani’s Reliance brings Shein back to India after 2020 app ban', 'events': [{'type': 'transport', 'trigger': 'brings', 'offset': [30, 36]}]}]
# [{'text': 'How things stand in China-US trade tensions as Trump 2.0 spawns tariffs', 'events': []}]
# [{'text': 'Singaporean playwright Jeremy Tiang wins Obie for Outstanding New Play', 'events': [{'type': 'elect', 'trigger': 'wins', 'offset': [36, 40]}]}]
# [{'text': 'How things stand in China-US trade tensions with Trump 2.0', 'events': []}]
# [{'text': 'Trump’s tariffs would reverse decades of integration between US and Mexico', 'events': []}]
# [{'text': 'Trump tariffs target loophole used by Chinese online retailers', 'events': []}]
# [{'text': 'Seeking light in dark times four years after Myanmar coup', 'events': [{'type': 'attack', 'trigger': 'coup', 'offset': [53, 57]}]}]
# [{'text': 'To Trump, tariffs are not a means but an end', 'events': []}]
# [{'text': 'China to challenge US tariffs under WTO, commerce ministry says', 'events': []}]
# [{'text': 'US Secretary of State Rubio to make debut in Panama as Trump threatens to take canal', 'events': []}]
# [{'text': 'Trump’s oil tariffs a boost for European and Asian refiners', 'events': []}]
# [{'text': 'Japan wary of taking another hit if Trump slaps tariffs on China', 'events': [{'type': 'attack', 'trigger': 'hit', 'offset': [29, 32]}]}]
# [{'text': 'Here’s what to know about Trump’s tariffs', 'events': []}]
# [{'text': 'Morning Briefing: Top stories from The Straits Times on Feb 2, 2025', 'events': []}]
# [{'text': 'Pump prices set to rise as Trump tariffs hit Canadian, Mexican oil', 'events': []}]
# [{'text': 'Trump tariffs begin for Canada, Mexico, China', 'events': []}]
# [{'text': "Reaction to Trump's imposition of tariffs on Mexico, Canada, China", 'events': []}]
# [{'text': 'Trump orders steep tariffs on goods from Mexico, Canada, China', 'events': []}]
# [{'text': 'Trump orders steep tariffs on goods from Mexico, Canada, China', 'events': []}]
# [{'text': 'Rubio to make debut in Panama as Trump threatens to take canal', 'events': []}]
# [{'text': 'Sleepless in Silicon Valley: A cheeky, Chinese upstart sparks a deep seek in America’s AI industry', 'events': []}]
# [{'text': 'India unveils tax cuts to boost middle-class spending and spur economic growth', 'events': []}]
# [{'text': 'Ex-US Federal Reserve adviser accused of stealing secrets for China', 'events': [{'type': 'chargeindict', 'trigger': 'accused', 'offset': [30, 37]}]}]
# [{'text': 'Want a million dollars? Get busy deciphering this ancient script', 'events': []}]
# [{'text': 'This week’s top reads from The Straits Times, Feb 1, 2025', 'events': []}]
# [{'text': 'Brisk business for pet sitters in China during CNY despite dismal economy', 'events': []}]
# [{'text': 'Nvidia expected to abide by US export curbs, Singapore laws, says MTI', 'events': []}]
# [{'text': 'Nvidia expected to abide by US curbs, S’pore laws, says MTI in reply to queries on DeepSeek’s chips', 'events': []}]
# [{'text': 'DeepSeek-Nvidia chips: Singapore says it expects companies to comply with its laws', 'events': []}]
# [{'text': 'Chinese workers in BYD Brazil factory signed contracts with abusive clauses, investigators say', 'events': []}]
# [{'text': 'Taiwan says government departments should not use DeepSeek, citing security concerns', 'events': []}]
# [{'text': 'Singaporean man sustains head, body injuries after defending family from attackers in Johor', 'events': [{'type': 'injure', 'trigger': 'injuries', 'offset': [36, 44]}, {'type': 'attack', 'trigger': 'attackers', 'offset': [73, 82]}]}]
# [{'text': 'Nvidia CEO Jensen Huang meets Trump at White House', 'events': [{'type': 'meet', 'trigger': 'meets', 'offset': [24, 29]}]}]
# [{'text': 'Trump says oil and gas tariffs may come around Feb 18', 'events': []}]
# [{'text': 'US stocks fall after White House confirms tariffs from Feb 1', 'events': []}]
# [{'text': 'Commentary: Does Volvo’s Chinese ownership threaten US national security?', 'events': []}]
# [{'text': 'Has Shenzhen eclipsed Hong Kong?', 'events': []}]
# [{'text': 'ST Picks: Has Shenzhen eclipsed Hong Kong?', 'events': []}]
# [{'text': 'White House says Trump to impose Canada, Mexico, China tariffs at weekend', 'events': []}]
# [{'text': 'North America braces for new Trump tariffs as Saturday deadline nears', 'events': []}]
# [{'text': 'White House says Trump to impose Canada, Mexico, China tariffs on Saturday', 'events': []}]
# [{'text': 'US probe into S’pore shows frustration over inadequacy of chip curbs on China', 'events': []}]
# [{'text': 'India joins global race to develop AI models', 'events': []}]
# [{'text': 'Singapore sends condolences to US over Washington air crash', 'events': [{'type': 'transport', 'trigger': 'sends', 'offset': [10, 15]}]}]
# [{'text': "How Trump's tariffs affect US trade with Canada, Mexico and China", 'events': []}]
# [{'text': 'Jason Teh slides into Thailand Masters s-finals after convincing win', 'events': []}]
# [{'text': 'Russia condemns Trump missile defence shield plan, accuses US of plotting to militarise space', 'events': []}]
# [{'text': "China's youth are skipping Chinese New Year. Here’s why", 'events': []}]
# [{'text': 'Protecting mangroves, creating coastal corridors can help horseshoe crabs thrive: NUS study', 'events': []}]
# [{'text': 'Malaysia kicks off big plans while Najib wants to go home', 'events': [{'type': 'transport', 'trigger': 'go', 'offset': [50, 52]}]}]
# [{'text': 'Evening Update: Today’s headlines from The Straits Times on Jan 31, 2025', 'events': []}]
# [{'text': 'Philippines’ Marcos seeks reassurances from Trump over alliance', 'events': []}]
# [{'text': 'US looking into whether DeepSeek used restricted AI chips acquired through other countries, source says', 'events': [{'type': 'transferownership', 'trigger': 'acquired', 'offset': [58, 66]}]}]
# [{'text': 'South Korea watchdog to question DeepSeek over user data', 'events': []}]
# [{'text': 'EU renews toothless Russia sanctions, retaining gas exemptions as Trump’s Ukraine ceasefire deal looms', 'events': []}]
# [{'text': 'LVMH sales growth raises hope for end to luxury downturn', 'events': []}]
# [{'text': 'Federated Hermes leverage Singapore HQ to target Asia’s wealth market', 'events': []}]
# [{'text': 'Apple forecast cheers investors after mixed holiday results', 'events': []}]
# [{'text': "Japan, US ministers express 'firm intent' to reinforce defence alliance", 'events': []}]
# [{'text': 'Apple shares rise after positive sales outlook signals iPhone recovery', 'events': []}]
# [{'text': 'Rubio warns of risk of China shutting down Panama Canal in any conflict', 'events': [{'type': 'attack', 'trigger': 'conflict', 'offset': [63, 71]}]}]
# [{'text': 'Morning Briefing: Top stories from The Straits Times on Jan 31, 2025', 'events': []}]
# [{'text': 'Pentagon workers used DeepSeek’s chatbot for days before block', 'events': []}]
# [{'text': 'Italy’s regulator blocks Chinese AI app DeepSeek on data protection', 'events': []}]
# [{'text': 'Commentary: DeepSeek and Huawei show US restrictions didn’t burst China’s tech ambitions. They made them bigger', 'events': []}]
# [{'text': 'This Sumatra island is known for tin production and deadly crocodile attacks. What’s the link?', 'events': [{'type': 'attack', 'trigger': 'attacks', 'offset': [69, 76]}]}]
# [{'text': 'Commentary: China’s New Year pay hike can’t mask its deeper economic troubles', 'events': [{'type': 'transfermoney', 'trigger': 'pay', 'offset': [29, 32]}]}]
# [{'text': 'Guide to Beijing: From cricket introductory sessions to dumpling making and hutong walks', 'events': []}]
# [{'text': 'Control of Panama Canal off the table in  Rubio talks, says country’s president', 'events': [{'type': 'meet', 'trigger': 'talks', 'offset': [48, 53]}]}]
# [{'text': 'Can Canada, Mexico and China avoid Trump tariffs on Feb 1?', 'events': []}]
# [{'text': 'Philippines president plans to meet Trump to discuss immigration policy', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [31, 35]}]}]
# [{'text': 'Philippines president plans to meet Trump to discuss immigration policy', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [31, 35]}]}]
# [{'text': 'Philippines president Marcos plans to meet Trump to discuss immigration policy', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [38, 42]}]}]
# [{'text': 'Microsoft shares fall as cloud forecast disappoints Wall Street', 'events': []}]
# [{'text': 'Coffee’s 94% rally finally hits the last holdouts for demand', 'events': [{'type': 'demonstrate', 'trigger': 'rally', 'offset': [13, 18]}]}]
# [{'text': 'Tesla’s profit fell sharply to $3.1 billion for last quarter of 2024', 'events': [{'type': 'transfermoney', 'trigger': 'profit', 'offset': [8, 14]}]}]
# [{'text': 'TikTok bidder to offer ‘significantly’ more than $27 billion', 'events': [{'type': 'transfermoney', 'trigger': 'offer', 'offset': [17, 22]}]}]
# [{'text': 'askST: Can the fluoride in drinking water really lower children’s IQ?', 'events': []}]
# [{'text': 'SoftBank in talks to invest up to $33.7 billion into OpenAI, FT reports', 'events': [{'type': 'transfermoney', 'trigger': 'invest', 'offset': [21, 27]}]}]
# [{'text': 'Morning Briefing: Top stories from The Straits Times on Jan 30, 2025', 'events': []}]
# [{'text': 'Trump commerce nominee says Canada, Mexico can avoid tariffs, vows stronger China tech curbs', 'events': []}]
# [{'text': 'OpenAI says Chinese firms try to copy US AI tech', 'events': []}]
# [{'text': 'Businesses must stay resilient amid challenges in 2025: Gan Kim Yong', 'events': []}]
# [{'text': "Italy's data watchdog has questions for DeepSeek", 'events': []}]
# [{'text': 'Fears of scam centre kidnaps keep Chinese tourists on edge in Thailand', 'events': [{'type': 'attack', 'trigger': 'kidnaps', 'offset': [21, 28]}]}]
# [{'text': 'LVMH’s subdued sales temper hopes for a rapid luxury rebound', 'events': [{'type': 'transferownership', 'trigger': 'sales', 'offset': [15, 20]}]}]
# [{'text': 'Fears of scam centre kidnaps keep Chinese tourists on edge in Thailand', 'events': [{'type': 'attack', 'trigger': 'kidnaps', 'offset': [21, 28]}]}]
# [{'text': 'Billionaire Arnault sees optimism in US after attending Trump inauguration', 'events': [{'type': 'startposition', 'trigger': 'inauguration', 'offset': [62, 74]}]}]
# [{'text': "DeepSeek's 'Sputnik moment' exposes holes in US chip curbs", 'events': []}]
# [{'text': 'Taiwan could help industry after Trump warns of chip tariffs', 'events': []}]
# [{'text': 'Microsoft probing if DeepSeek-linked group improperly obtained OpenAI data', 'events': []}]
# [{'text': 'Hundreds of millions in Asia celebrate Year of the Snake', 'events': []}]
# [{'text': 'Hundreds of millions in Asia celebrate Year of the Snake', 'events': []}]
# [{'text': 'While You Were Sleeping: 5 stories you might have missed, Jan 29, 2025', 'events': []}]
# [{'text': 'Commentary: DeepSeek - how a Chinese AI company just changed the rules of tech-geopolitics', 'events': []}]
# [{'text': 'ST Picks: Not a coincidence? DeepSeek’s debut on Trump’s first week in office', 'events': []}]
# [{'text': 'China’s export ban on engineers and equipment disrupts manufacturing overseas', 'events': [{'type': 'transferownership', 'trigger': 'export', 'offset': [8, 14]}]}]
# [{'text': 'EU’s Kallas, US’ Rubio discuss Ukraine in first phone call', 'events': [{'type': 'phonewrite', 'trigger': 'call', 'offset': [54, 58]}]}]
# [{'text': 'China wants to see US, Russian nuclear disarmament efforts before talks', 'events': [{'type': 'meet', 'trigger': 'talks', 'offset': [66, 71]}]}]
# [{'text': 'Images show China building huge fusion research facility, analysts say', 'events': [{'type': 'artifact', 'trigger': 'building', 'offset': [18, 26]}]}]
# [{'text': 'DeepSeek may be the best Chinese New Year gift to China this year, but can it sink its US rivals?', 'events': []}]
# [{'text': 'Wang Xinyu wants to make tennis ‘even bigger in China’', 'events': []}]
# [{'text': 'UK PM says economy is starting to turn around', 'events': []}]
# [{'text': 'China’s new face of AI: Who is DeepSeek founder Liang Wenfeng?', 'events': []}]
# [{'text': 'Antique dealer admits to selling customer’s Qing Dynasty vase to pay off his debts', 'events': [{'type': 'transferownership', 'trigger': 'selling', 'offset': [25, 32]}, {'type': 'transfermoney', 'trigger': 'pay', 'offset': [65, 68]}]}]
# [{'text': 'Philippines to train with US Typhon missile system next month', 'events': []}]
# [{'text': '‘Made in China’: Pride, pleasant surprise from Chinese netizens as DeepSeek jolts global AI scene', 'events': []}]
# [{'text': "Breakout Chinese AI DeepSeek 'programmed' to toe the party line", 'events': []}]
# [{'text': '‘A lot is up in the air’: Is Chinese firm DeepSeek’s AI model as impactful as it claims?', 'events': []}]
# [{'text': 'Global markets sink as DeepSeek triggers AI rethink, with tech stocks hardest hit', 'events': []}]
# [{'text': 'American AI firms try to poke holes in disruptive DeepSeek', 'events': []}]
# [{'text': 'Caution Ahead! Vietnam’s drivers are suddenly following the rules', 'events': []}]
# [{'text': 'China cashes in on winter economy as tourists flock to Harbin', 'events': [{'type': 'transport', 'trigger': 'flock', 'offset': [46, 51]}]}]
# [{'text': "Trump emphasises 'fair' trade, discusses defence buys and immigration with Modi", 'events': []}]
# [{'text': 'DPM Heng seeks deeper Singapore, Germany ties to promote free trade, innovation', 'events': []}]
# [{'text': 'China planned DeepSeek’s dramatic debut on world stage to send signal to Trump: US AI expert', 'events': []}]
# [{'text': 'How Donald Trump weaponised tariffs', 'events': []}]
# [{'text': 'Rare China support shows Vanke may be too big to fail', 'events': []}]
# [{'text': "China's AI drive hammers tech stocks in Japan, Australia", 'events': []}]
# [{'text': 'Chinese AI is catching up, posing a dilemma for Donald Trump', 'events': []}]
# [{'text': 'DeepSeek’s AI model tests limits of US curbs on Nvidia chips', 'events': []}]
# [{'text': 'Trump: DeepSeek’s AI should be a wake-up call to US industry', 'events': []}]
# [{'text': 'What is China’s DeepSeek and why is it freaking out the AI world?', 'events': []}]
# [{'text': 'DeepSeek hit by cyberattack as users flock to Chinese AI startup', 'events': [{'type': 'transport', 'trigger': 'flock', 'offset': [37, 42]}, {'type': 'attack', 'trigger': 'hit', 'offset': [9, 12]}]}]
# [{'text': 'Nvidia loses nearly US$600b in value as Chinese AI firm jolts tech shares', 'events': [{'type': 'transferownership', 'trigger': 'jolts', 'offset': [56, 61]}]}]
# [{'text': 'Commentary: How trade-reliant Malaysia can navigate Trump’s presidency', 'events': []}]
# [{'text': 'While You Were Sleeping: 5 stories you might have missed, Jan 28, 2025', 'events': []}]
# [{'text': 'US investigates worrying bird flu strain on duck farm in California', 'events': []}]
# [{'text': 'Trump emphasises ‘fair’ trade and defence buys in call with India’s Modi', 'events': []}]
# [{'text': 'DeepSeek’s overnight rise to fame strains system, draws attacks', 'events': []}]
# [{'text': 'Trump calls for ‘Iron Dome’ for US Homeland missile defence', 'events': []}]
# [{'text': 'China signals willingness to accept  Chinese nationals repatriated from the US', 'events': [{'type': 'transport', 'trigger': 'repatriated', 'offset': [55, 66]}]}]
# [{'text': 'Tesla, BMW take EU to court over China EV tariffs', 'events': []}]
# [{'text': "China's Xi strikes bullish tone in speech to mark Chinese New Year", 'events': [{'type': 'broadcast', 'trigger': 'speech', 'offset': [35, 41]}]}]
# [{'text': 'China promises to take back illegal migrants after Trump threats', 'events': []}]
# [{'text': 'China says ‘extremely unlikely’ Covid-19 pandemic came from lab leak', 'events': []}]
# [{'text': 'Chinese lion dance troupe shrugs off patriarchal past', 'events': []}]
# [{'text': 'Philippines, US, Vietnam, Indonesia train for maritime law enforcement cooperation', 'events': []}]
# [{'text': 'Philippines, US, Vietnam, Indonesia train for maritime law enforcement cooperation', 'events': []}]
# [{'text': 'Chinese AI startup DeepSeek overtakes ChatGPT on Apple App Store', 'events': []}]
# [{'text': 'DeepSeek hit by cyber attack as users flock to Chinese AI start-up', 'events': [{'type': 'transport', 'trigger': 'flock', 'offset': [38, 43]}, {'type': 'attack', 'trigger': 'hit', 'offset': [9, 12]}]}]
# [{'text': 'Chinese AI assistant DeepSeek tops iPhone downloads, spurs Asia stocks', 'events': []}]
# [{'text': "From 60% to 10%: Is Trump's China tariff proposal a softened stance or tactical move?", 'events': [{'type': 'transfermoney', 'trigger': 'tariff', 'offset': [34, 40]}]}]
# [{'text': 'New Zealand foreign minister confident of stronger US relations', 'events': []}]
# [{'text': 'New World debt turmoil rocks one of Hong Kong’s richest families', 'events': []}]
# [{'text': 'Instil hope, not fear of tariffs, in global population to raise consumption and growth: BlackRock', 'events': []}]
# [{'text': 'Trump, Starmer talk trade on first call since inauguration', 'events': [{'type': 'startposition', 'trigger': 'inauguration', 'offset': [46, 58]}]}]
# [{'text': 'US Fed prepares to pause this week in first rate decision since Trump’s inauguration', 'events': [{'type': 'startposition', 'trigger': 'inauguration', 'offset': [72, 84]}]}]
# [{'text': 'Travel News: Ed Sheeran is first international artiste to hold concert in Bhutan', 'events': [{'type': 'meet', 'trigger': 'concert', 'offset': [63, 70]}]}]
# [{'text': 'IN FOCUS: The naturalisation push in Southeast Asian football – do foreign-born players guarantee success?', 'events': []}]
# [{'text': 'Commentary: China has invested billions in ports around the world. This is why the West is so concerned', 'events': [{'type': 'transfermoney', 'trigger': 'invested', 'offset': [22, 30]}]}]
# [{'text': 'Trump discussing TikTok purchase with multiple people, decision in 30 days', 'events': [{'type': 'transferownership', 'trigger': 'purchase', 'offset': [24, 32]}]}]
# [{'text': 'Changi Airport poised for growth in 2025 and beyond, but challenges to its hub status loom', 'events': []}]
# [{'text': 'Thai badminton stars Kunlavut Vitidsarn, Ratchanok Intanon reign supreme at Indonesia Masters', 'events': []}]
# [{'text': 'China’s first corgi police dog loses ‘performance bonus’ after it sleeps on the job, pees in basin', 'events': []}]
# [{'text': 'India, a big source of illegal migration, hopes to navigate the Trump storm', 'events': [{'type': 'transport', 'trigger': 'migration', 'offset': [31, 40]}]}]
# [{'text': 'India – a large source of illegal migration – hopes to navigate Trump crackdown', 'events': [{'type': 'transport', 'trigger': 'migration', 'offset': [34, 43]}]}]
# [{'text': 'Trump casts chill over US wind energy sector', 'events': []}]
# [{'text': "US Fed prepares to pause in first interest rate decision since Trump's inauguration", 'events': [{'type': 'startposition', 'trigger': 'inauguration', 'offset': [71, 83]}]}]
# [{'text': 'Meet the groomer Singapore stars turn to when their pets need sprucing up', 'events': []}]
# [{'text': 'Major Chinese port hit by congestion ahead of major holiday, Trump tariff threat', 'events': []}]
# [{'text': "Remember Einstein? Meet the 'bald ang moh guy' who taught Singapore millennials how to draw on TV", 'events': []}]
# [{'text': 'White House in talks to have Oracle and US investors take over TikTok: NPR', 'events': [{'type': 'meet', 'trigger': 'talks', 'offset': [15, 20]}]}]
# [{'text': 'Trump says he may consider rejoining WHO', 'events': []}]
# [{'text': 'While You Were Sleeping: 5 stories you might have missed, Jan 26, 2025', 'events': []}]
# [{'text': 'CIA now favours ‘lab leak’ theory to explain Covid-19 origins', 'events': []}]
# [{'text': 'Squash junior Ong Zhe Sim gets 6-month probation for breaching athletes’ agreement', 'events': [{'type': 'releaseparole', 'trigger': 'probation', 'offset': [39, 48]}]}]
# [{'text': 'In China, rare dissent over a programme to save on drug costs', 'events': []}]
# [{'text': 'How to make it in America: The pressures and pitfalls for Chinese brands going global', 'events': []}]
# [{'text': 'Bullish on the CBD: Back to office with more dining options', 'events': []}]
# [{'text': 'Pete Hegseth narrowly wins confirmation to become US defence secretary', 'events': [{'type': 'startposition', 'trigger': 'become', 'offset': [43, 49]}]}]
# [{'text': 'EU military chief says it would make sense to station European troops in Greenland', 'events': []}]
# [{'text': 'Commentary: What Trump wants in Latin America isn’t actually the Panama Canal', 'events': []}]
# [{'text': 'Trump pumps coal as answer to AI power needs but any boost could be short-lived', 'events': []}]
# [{'text': 'Stock analysts’ guide to prosperity in 2025', 'events': []}]
# [{'text': 'In phone call, China’s Wang tells Rubio leaders have set tone and direction of US-China ties', 'events': [{'type': 'phonewrite', 'trigger': 'call', 'offset': [9, 13]}]}]
# [{'text': 'Heard in Davos: What we learned from the WEF in 2025', 'events': []}]
# [{'text': 'Police in Spain break up Chinese prostitution ring', 'events': []}]
# [{'text': "ECB pitches digital euro as response to Trump's crypto push", 'events': []}]
# [{'text': "Trump's deportation operation underway, hundreds of migrants arrested: White House", 'events': [{'type': 'transport', 'trigger': 'deportation', 'offset': [8, 19]}, {'type': 'arrestjail', 'trigger': 'arrested', 'offset': [61, 69]}]}]
# [{'text': 'Chinese firms boost shareholder returns via dividends and buybacks', 'events': [{'type': 'transfermoney', 'trigger': 'returns', 'offset': [32, 39]}, {'type': 'transferownership', 'trigger': 'buybacks', 'offset': [58, 66]}]}]
# [{'text': 'Gambling tycoon abused in Thai jail after saying he spied for China, lawyers say', 'events': [{'type': 'arrestjail', 'trigger': 'jail', 'offset': [31, 35]}]}]
# [{'text': "Trump's deportation operation underway, hundreds of migrants arrested: White House", 'events': [{'type': 'transport', 'trigger': 'deportation', 'offset': [8, 19]}, {'type': 'arrestjail', 'trigger': 'arrested', 'offset': [61, 69]}]}]
# [{'text': 'Trump’s blistering start - why the rush and its impact on Asia', 'events': []}]
# [{'text': 'Firms project higher revenues from better productivity and expanding overseas with help from EnterpriseSG', 'events': [{'type': 'transfermoney', 'trigger': 'revenues', 'offset': [21, 29]}]}]
# [{'text': 'Singdollar to weaken with further MAS easing but economists rule out sharp decline', 'events': []}]
# [{'text': "Trump says he'd 'rather not' put tariffs on China", 'events': []}]
# [{'text': "Trump says he would 'rather not' put tariffs on China", 'events': []}]
# [{'text': "Trump says he will reach out to North Korea's Kim again", 'events': [{'type': 'meet', 'trigger': 'reach', 'offset': [19, 24]}]}]
# [{'text': 'Trump defence pick Hegseth narrowly survives US Senate test vote', 'events': []}]
# [{'text': '‘I feel very safe here’: Chinese nationals in Thailand debunk online claims fanning scam trafficking fears', 'events': []}]
# [{'text': 'Invest in the US or pay tariffs, says Trump in Davos address', 'events': [{'type': 'transfermoney', 'trigger': 'pay', 'offset': [20, 23]}]}]
# [{'text': 'China’s frugal tourists avoid far-flung trips over Lunar New Year holiday', 'events': [{'type': 'transport', 'trigger': 'trips', 'offset': [40, 45]}]}]
# [{'text': "COP30 chief praises China's 'extraordinary' climate progress", 'events': []}]
# [{'text': 'Billionaire McCourt says he is open to teaming up on a TikTok bid', 'events': []}]
# [{'text': 'Trump defence pick Hegseth narrowly survives US Senate test vote', 'events': []}]
# [{'text': 'Commentary: Trump’s ‘ridiculous war must end now’ warning to Putin is a surprise', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [32, 35]}]}]
# [{'text': 'Changi Airport to focus on e-commerce, pharmaceutical shipments as cargo capacity tightens', 'events': []}]
# [{'text': 'Trump says he wants to meet Putin soon to ensure end of Ukraine war', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [64, 67]}]}]
# [{'text': "Trump says he's ready to meet Putin 'immediately' to secure end of Ukraine war", 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [75, 78]}]}]
# [{'text': 'Trump tells Davos he will demand lower interest rates, oil prices', 'events': []}]
# [{'text': 'Trump to world companies: Make products in US or face tariffs', 'events': []}]
# [{'text': "China plans to build world's largest hydropower dam in Tibet, could cost as much as US$137b", 'events': [{'type': 'artifact', 'trigger': 'build', 'offset': [15, 20]}]}]
# [{'text': 'Philippines to pick venue soon for second South China Sea case against Beijing', 'events': []}]
# [{'text': 'Manila to pick venue soon for second South China Sea case against Beijing', 'events': []}]
# [{'text': 'A US$500 billion investment plan says a lot about Trump’s AI priorities', 'events': []}]
# [{'text': 'Luxury brands look to US consumers to drive recovery', 'events': []}]
# [{'text': 'OpenAI, SoftBank each commit $25.7 billion to Stargate AI project, the Information reports', 'events': [{'type': 'transfermoney', 'trigger': 'commit', 'offset': [22, 28]}]}]
# [{'text': 'American firms in China fearful of US-China trade turmoil at 5-year high, shows survey', 'events': []}]
# [{'text': 'American firms in China fearful of US-China trade turmoil at 5-year high, survey shows', 'events': []}]
# [{'text': "Albania's Rama hints at softening of TikTok ban", 'events': []}]
# [{'text': 'Japan’s exports rise as world awaits Trump tariffs', 'events': [{'type': 'transferownership', 'trigger': 'exports', 'offset': [8, 15]}]}]
# [{'text': 'Does China control the Panama Canal, as Trump claims?', 'events': []}]
# [{'text': 'Morning Briefing: Top stories from The Straits Times on Jan 23, 2025', 'events': []}]
# [{'text': 'Marco Rubio affirms ‘ironclad’ US commitment to Philippines', 'events': []}]
# [{'text': 'S&P 500 hits record high with boost from Netflix results, AI investment plan', 'events': []}]
# [{'text': 'ST Picks: Davos elites grapple with realities of Trump’s return', 'events': [{'type': 'endposition', 'trigger': 'return', 'offset': [57, 63]}]}]
# [{'text': 'Trump threatens Russia, other countries with sanctions, tariffs if Ukraine deal not reached', 'events': []}]
# [{'text': 'ST Picks: Could TikTok become China’s bargaining chip with the US?', 'events': []}]
# [{'text': 'Ships carrying missile propellant to sail from China to Iran, FT reports', 'events': [{'type': 'transport', 'trigger': 'sail', 'offset': [37, 41]}]}]
# [{'text': 'Trump says tariff on Chinese imports could come as soon as Feb 1', 'events': []}]
# [{'text': "Malaysia's Anwar says don't single out China in sea tensions", 'events': []}]
# [{'text': 'Malaysia’s Anwar says China should not be singled out in sea tensions', 'events': []}]
# [{'text': 'Malaysia’s Anwar says China should not be singled out in South China Sea tensions', 'events': []}]
# [{'text': 'French and German leaders to meet under cloud of Trump tariff threats', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [29, 33]}]}]
# [{'text': 'French and German leaders meet to discuss Trump tariff threats', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [26, 30]}]}]
# [{'text': 'Day 2, and Donald Trump is already reshaping the global economy', 'events': []}]
# [{'text': 'Counting down to Seventeen: 17 facts to know about the K-pop boy band', 'events': []}]
# [{'text': 'EU hawks back Trump call to boost defence spending', 'events': []}]
# [{'text': "EU's top diplomat backs Trump call to boost defence spending", 'events': []}]
# [{'text': 'STI ends 0.4% lower amid mixed Asian markets and Trump’s tariff remarks', 'events': []}]
# [{'text': '‘Be serious’, Panama president tells Trump amid ‘invasion’ threat', 'events': [{'type': 'attack', 'trigger': 'invasion', 'offset': [49, 57]}]}]
# [{'text': 'Thai PM makes AI video appeal to Chinese tourists', 'events': []}]
# [{'text': '‘Very volatile four years’: What Trump’s early moves say about his second US presidency', 'events': []}]
# [{'text': 'China and US partners are moving closer as Trump returns to the White House', 'events': [{'type': 'transport', 'trigger': 'returns', 'offset': [49, 56]}]}]
# [{'text': 'EV supply chains to go global, says battery boss, but fears remain over China’s dominance', 'events': []}]
# [{'text': 'Trump reversing climate action progress will have domestic and international ramifications, experts say', 'events': []}]
# [{'text': 'China vows to defend ‘interests’ against Trump tariff threats', 'events': []}]
# [{'text': 'China orders pay cap at state-owned financial firms, sources say', 'events': [{'type': 'transfermoney', 'trigger': 'pay', 'offset': [13, 16]}]}]
# [{'text': 'Panama complains to UN over Trump canal threat, starts audit', 'events': []}]
# [{'text': 'Nimble, flexible, but with guardrails: DPM Gan lays out Singapore’s AI approach at Davos panel', 'events': []}]
# [{'text': 'Malaysia Edition: Sun’s not shining on solar panel makers | Cops battle the bulge', 'events': [{'type': 'attack', 'trigger': 'battle', 'offset': [65, 71]}]}]
# [{'text': 'TikTok owner ByteDance plans to spend $16b on AI chips in 2025, FT reports', 'events': [{'type': 'transfermoney', 'trigger': 'spend', 'offset': [32, 37]}]}]
# [{'text': 'TikTok owner ByteDance plans to spend $16b on AI chips in 2025', 'events': [{'type': 'transfermoney', 'trigger': 'spend', 'offset': [32, 37]}]}]
# [{'text': "South Korea's birth rate set to rise for the first time in nine years", 'events': [{'type': 'beborn', 'trigger': 'birth', 'offset': [14, 19]}]}]
# [{'text': 'Trump says he will impose 10% tariffs on Chinese imports on Feb 1', 'events': []}]
# [{'text': 'Carbon and nature markets not perfect, but should not be dismissed: WEF panel', 'events': []}]
# [{'text': '‘We are very worried’: Vietnamese firms watch out for Trump’s potential tariffs', 'events': [{'type': 'transfermoney', 'trigger': 'tariffs', 'offset': [72, 79]}]}]
# [{'text': 'Changi Airport’s 2024 passenger traffic hit 99.1% of pre-pandemic levels', 'events': [{'type': 'attack', 'trigger': 'hit', 'offset': [40, 43]}]}]
# [{'text': 'China welcomes back Hollywood movies in bid to boost spending', 'events': []}]
# [{'text': 'Trump stirs tariff pot with fresh threats on EU, Feb 1 China deadline', 'events': []}]
# [{'text': 'Trump delivers fresh tariff threats against EU, China', 'events': []}]
# [{'text': 'Canada vows strong response, Mexico urges calm in face of Trump threats', 'events': []}]
# [{'text': "Trump says EU 'in for tariffs', warns of 10% rate on China", 'events': []}]
# [{'text': 'TikTok users anxiously await its return to US app stores', 'events': []}]
# [{'text': 'Morning Briefing: Top stories from The Straits Times on Jan 22, 2025', 'events': []}]
# [{'text': 'Trump strips security detail from former adviser John Bolton', 'events': [{'type': 'endposition', 'trigger': 'former', 'offset': [34, 40]}]}]
# [{'text': 'Quad foreign ministers meet US top diplomat Marco Rubio', 'events': [{'type': 'meet', 'trigger': 'meet', 'offset': [23, 27]}]}]
# [{'text': 'IN FOCUS: Is influx of JB property buyers from Singapore, China pricing out locals?', 'events': [{'type': 'transferownership', 'trigger': 'buyers', 'offset': [35, 41]}]}]
# [{'text': 'Spared on Trump’s first day in office, a wary Beijing waits', 'events': []}]
# [{'text': 'ST Picks: Will Trump follow through with his trade tariff threats?', 'events': []}]
# [{'text': '‘The fun stops here’: Davos elites at economic forum grapple with realities of Trump’s return', 'events': [{'type': 'meet', 'trigger': 'forum', 'offset': [47, 52]}]}]
# [{'text': 'Trump plans to fire over 1,000 Biden appointees, celebrity chef Jose Andres says he already resigned', 'events': [{'type': 'endposition', 'trigger': 'resigned', 'offset': [92, 100]}, {'type': 'endposition', 'trigger': 'fire', 'offset': [15, 19]}]}]
# [{'text': 'Facing Trump and Musk, EU lawmakers seek sure footing', 'events': []}]
# [{'text': "Trump's US pullout order leaves WHO budget tightened", 'events': []}]
# [{'text': 'Risk of US cutting itself off from China low, other countries can help manage rivalry: PM Wong', 'events': []}]
# [{'text': "Hong Kong seeks better US ties but blasts 'shameless' former VP Pence", 'events': [{'type': 'endposition', 'trigger': 'former', 'offset': [54, 60]}, {'type': 'attack', 'trigger': 'blasts', 'offset': [35, 41]}]}]
# [{'text': 'China’s vice-premier lunches with Dimon, Schwarzman and other Davos financiers', 'events': [{'type': 'meet', 'trigger': 'lunches', 'offset': [21, 28]}]}]
# [{'text': 'Marco Rubio becomes US Secretary of State, emphasises ‘America First’ agenda', 'events': [{'type': 'startposition', 'trigger': 'becomes', 'offset': [12, 19]}]}]
# [{'text': 'Paula Badosa almost quit tennis in 2024, now she’s in Australian Open semi-final', 'events': [{'type': 'endposition', 'trigger': 'quit', 'offset': [20, 24]}]}]
# [{'text': 'Yemen vice-president says Trump return pivotal in fight against Iran backed-Houthis', 'events': [{'type': 'attack', 'trigger': 'fight', 'offset': [50, 55]}]}]
# [{'text': 'Trump holds off on China-specific tariffs on his first day in office', 'events': []}]
# [{'text': 'EU, China warn against trade friction at Davos after Trump return', 'events': [{'type': 'transport', 'trigger': 'return', 'offset': [59, 65]}]}]
# [{'text': 'Under Trump, could TikTok become China’s bargaining chip?', 'events': []}]
# [{'text': "Taiwan's opposition-controlled parliament cuts 2025 budget", 'events': []}]
# [{'text': "Russia's Putin, China's Xi speak just hours after Trump inauguration", 'events': [{'type': 'startposition', 'trigger': 'inauguration', 'offset': [56, 68]}]}]
# [{'text': 'Singapore’s STI ends 0.3% lower as investors digest Trump 2.0, no immediate China tariffs', 'events': []}]
# [{'text': 'Xi and Putin discuss ties with Trump, Ukraine and Taiwan', 'events': []}]
# [{'text': 'China’s ‘iPhone city’ Zhengzhou braces for uncertainty as Trump returns to office', 'events': [{'type': 'startposition', 'trigger': 'returns', 'offset': [64, 71]}]}]
# [{'text': 'China says it hopes for cooperation with US on trade under Trump', 'events': []}]
# [{'text': "WHO 'regrets' Trump decision to pull US from organisation", 'events': []}]
# [{'text': 'Trump orders US exit from the World Health Organization', 'events': []}]
# [{'text': 'Social media apps are changing how people buy and read books in China', 'events': []}]
# [{'text': 'What does Shanghai’s shrinking expatriate population mean for China?', 'events': []}]
# [{'text': 'No day-one tariffs from Trump, but he says Canada, Mexico may get duties Feb 1', 'events': []}]
# [{'text': 'Trump’s anti-climate steps a setback for the world and especially the US: Experts', 'events': []}]
# [{'text': 'Trump’s tariff tease: Not just yet, but threats loom', 'events': []}]
# [{'text': 'China, EU, Ukraine leaders take Davos stage under Trump shadow', 'events': []}]
# [{'text': 'Panama opens audit of Chinese port operator while Trump threatens to take canal back', 'events': []}]
# [{'text': 'Gold extends gain, greenback volatile after President Trump first moves in office', 'events': [{'type': 'endposition', 'trigger': 'moves', 'offset': [66, 71]}]}]
# [{'text': 'Early action plans for heat a priority for Red Cross and Red Crescent network', 'events': []}]
# [{'text': 'Trump’s inauguration pledge to expand US territory: What’s at stake as he eyes Greenland, Panama Canal?', 'events': [{'type': 'startposition', 'trigger': 'inauguration', 'offset': [8, 20]}]}]
# [{'text': 'Arctic’s ‘sad’ future, Panama Canal ‘tragedy’? Trump’s inauguration pledge to expand US soil fuels concerns', 'events': [{'type': 'demonstrate', 'trigger': 'inauguration', 'offset': [55, 67]}]}]
# [{'text': "Commentary: Trump's 'America First' may be good for smaller countries", 'events': []}]
# [{'text': 'After taking office, Trump pardons Jan 6 rioters, signs sweeping orders on immigration and energy', 'events': [{'type': 'pardon', 'trigger': 'pardons', 'offset': [27, 34]}]}]
# [{'text': 'Morgan Stanley boosts senior Asia banker bonuses by up to 40%', 'events': []}]
# [{'text': "Trump vows US 'taking back' Panama Canal despite 'peacemaker' pledge", 'events': []}]
# [{'text': 'Trump signs executive order withdrawing from the World Health Organisation', 'events': [{'type': 'endposition', 'trigger': 'withdrawing', 'offset': [28, 39]}]}]
# [{'text': 'Trump signs executive order withdrawing from the World Health Organization', 'events': [{'type': 'endposition', 'trigger': 'withdrawing', 'offset': [28, 39]}]}]
# [{'text': 'Trump says to unleash American fossil fuels, halt climate cooperation', 'events': []}]
# [{'text': 'After inauguration, US President Trump signs orders in front of a cheering crowd', 'events': [{'type': 'demonstrate', 'trigger': 'inauguration', 'offset': [6, 18]}]}]
# [{'text': 'Trump withdraws from Paris climate agreement, again', 'events': [{'type': 'transport', 'trigger': 'withdraws', 'offset': [6, 15]}]}]
# [{'text': 'TikTok refugees are helping power up some China consumer stocks', 'events': []}]
# [{'text': 'US Senate confirms Marco Rubio as Secretary of State', 'events': []}]
# [{'text': 'Trump vows to plant flag on Mars, omits mention of Moon return', 'events': []}]
# [{'text': 'Trump holds off on immediate China tariffs, calls for study', 'events': []}]
# [{'text': 'While You Were Sleeping: 5 stories you might have missed, Jan 21, 2025', 'events': []}]
# [{'text': 'Cartier-owner Richemont beats expectations as jewellery sales boom', 'events': []}]
# [{'text': 'Forget Trump, Taiwan faces much bigger problems', 'events': []}]
# [{'text': 'TikTok’s on and off ban: Here’s a breakdown of what happened', 'events': []}]
# [{'text': "'We're back. I'm excited': Portraits of the crowd at Trump's inauguration", 'events': [{'type': 'demonstrate', 'trigger': 'inauguration', 'offset': [61, 73]}]}]
# ...
# [{'text': 'UK researchers find new methods to solve sticky issue of ‘honey laundering’', 'events': []}]
# [{'text': "US, Philippines launch war games a day after China's Taiwan drills", 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [23, 26]}]}]
# [{'text': 'China may raise US$850 billion in new debt over three years to spur growth, says report', 'events': []}]
# [{'text': 'Hong Kong policy address seen pivoting from security to economic growth', 'events': []}]
# [{'text': 'US weighs capping exports of AI chips from Nvidia and AMD to some countries', 'events': [{'type': 'transferownership', 'trigger': 'exports', 'offset': [18, 25]}]}]
# [{'text': 'Japan election campaigns kick off for Oct 27 vote', 'events': [{'type': 'elect', 'trigger': 'election', 'offset': [6, 14]}]}]
# [{'text': 'What is driving fans of China’s elite athletes crazier than those who idolise entertainment stars?', 'events': []}]
# [{'text': 'China moves to tax ultra-rich for overseas investment gains', 'events': []}]
# [{'text': "'Pandas are coming': Two new bears depart China for US capital", 'events': [{'type': 'transport', 'trigger': 'depart', 'offset': [35, 41]}]}]
# [{'text': 'VW, BMW and Mercedes getting left in the dust by China’s EVs', 'events': []}]
# [{'text': 'Curious about Mongolia’s culture? This theatre spectacle coming to MBS shows it’s more than stunning landscapes', 'events': []}]
# [{'text': 'Commentary: China’s support for Iran in conflict with Israel is a double-edged sword', 'events': [{'type': 'attack', 'trigger': 'conflict', 'offset': [40, 48]}]}]
# [{'text': 'Commentary: Timely decision to award Nobel Peace Prize to Japanese atomic bomb survivors', 'events': [{'type': 'elect', 'trigger': 'award', 'offset': [31, 36]}]}]
# [{'text': 'Commentary: Chinese support for Iran complicates relations with Israel and, possibly, Gulf states', 'events': []}]
# [{'text': 'India withdraws Canada envoy named in probe, expels diplomats', 'events': [{'type': 'endposition', 'trigger': 'expels', 'offset': [45, 51]}, {'type': 'transport', 'trigger': 'withdraws', 'offset': [6, 15]}]}]
# [{'text': 'Usha Chandradas on Income Tax (Amendment) Bill and Multinational Enterprise (Minimum Tax) Bill', 'events': []}]
# [{'text': "For Europe's economy, US election risks outweigh upside", 'events': [{'type': 'elect', 'trigger': 'election', 'offset': [25, 33]}]}]
# [{'text': "Philippine defence minister doubts China's intent on South China Sea code", 'events': []}]
# [{'text': 'Singapore banks expect lower rates, China stimulus to boost wealth business', 'events': []}]
# [{'text': 'Singapore authorities developing guidelines to help employers manage extreme weather risks', 'events': []}]
# [{'text': "China's shows of force against Taiwan", 'events': [{'type': 'attack', 'trigger': 'force', 'offset': [17, 22]}]}]
# [{'text': 'Bitter family feud plays out in South Korea for control of metals empire', 'events': [{'type': 'attack', 'trigger': 'feud', 'offset': [14, 18]}]}]
# [{'text': 'Yangzijiang Shipbuilding discloses customers began arbitration proceedings for $1.09 billion', 'events': [{'type': 'trialhearing', 'trigger': 'proceedings', 'offset': [63, 74]}]}]
# [{'text': 'Trump says could support using US military against Americans', 'events': [{'type': 'attack', 'trigger': 'using', 'offset': [25, 30]}]}]
# [{'text': 'Commentary: I was adopted from China. That’s my lifelong identity', 'events': []}]
# [{'text': 'Small businesses, big challenges: The reality of China’s post-US Fed cut economy', 'events': []}]
# [{'text': 'Commentary: The Russian relationship with North Korea opens the door to further nuclearisation', 'events': []}]
# [{'text': 'Commentary: I was the daughter my parents didn’t keep', 'events': []}]
# [{'text': 'Commentary: Russia’s turn towards North Korea for help in Ukraine war fuels Kim’s nuclear ambitions', 'events': [{'type': 'attack', 'trigger': 'war', 'offset': [28, 31]}]}]
# [{'text': 'New leaders ignite buzz at Asean Summits – in more ways than one', 'events': []}]
# [{'text': 'Markets hit new highs as US economy, China stimulus remain the focus', 'events': []}]
# [{'text': 'China wants to draw more foreign hospitals, but hurdles remain significant', 'events': []}]
# [{'text': 'Taiwan spots Chinese carrier sailing its south, China military video says ‘prepared for battle’', 'events': [{'type': 'attack', 'trigger': 'battle', 'offset': [88, 94]}]}]
# [{'text': 'US firms brace for more tariffs as election approaches', 'events': [{'type': 'elect', 'trigger': 'election', 'offset': [35, 43]}]}]
# [{'text': 'Pakistan frets over security ahead of key summit that includes Russia, China and India', 'events': [{'type': 'meet', 'trigger': 'summit', 'offset': [42, 48]}]}]
# [{'text': 'Volkswagen’s woes reflect a stagnant German economy', 'events': []}]
# [{'text': 'ST Picks: Young S’poreans on the fast track to financial freedom', 'events': []}]
# [{'text': 'Integration not isolation: Asean and partners must show a different way forward, says PM Wong', 'events': []}]
# [{'text': 'In elections we trust not, say many Americans', 'events': [{'type': 'elect', 'trigger': 'elections', 'offset': [3, 12]}]}]
# [{'text': 'Nuclear deterrence still at heart of great power strategy: Experts', 'events': []}]
# [{'text': 'India is now Russia’s No. 2 supplier of restricted technology', 'events': []}]
# [{'text': "China says it will 'significantly increase' debt to revive economic growth", 'events': []}]
# [{'text': 'Journey to a million: Young Singaporeans on the fast track to ‘financial freedom’ bare all', 'events': []}]
# [{'text': 'Elephant playground slides fan nostalgia for Taiwanese', 'events': []}]
# [{'text': 'Japan PM Ishiba stresses continuity to Asean after ‘Asian Nato’ proposal stokes anxiety', 'events': []}]
# [{'text': 'Internal TikTok documents show prioritisation of traffic over well-being', 'events': []}]
# [{'text': 'US Treasury calls for new IMF, World Bank steps to ease liquidity strains', 'events': []}]
# [{'text': 'Progress on key issues remains slow as ASEAN summit concludes: Analysts', 'events': [{'type': 'meet', 'trigger': 'summit', 'offset': [45, 51]}]}]
# [{'text': 'East Asia Summit: S’pore urges Asean partners to ‘lean forward’ to help stop violence in Myanmar', 'events': [{'type': 'attack', 'trigger': 'violence', 'offset': [77, 85]}]}]
# [{'text': 'Global tech cooperation key to tackling cross-border challenges: Josephine Teo in China', 'events': []}]
# [{'text': 'Philippines calls for urgency from China, Asean in negotiating South China Sea code', 'events': []}]
# [{'text': "Perception vs reality - nuclear energy is safer than many think but there's still great fear around it", 'events': []}]
# [{'text': 'Clashes on South China Sea, Ukraine dominate Asia summit', 'events': [{'type': 'attack', 'trigger': 'Clashes', 'offset': [0, 7]}]}]
# [{'text': 'Singapore shares track Wall Street losses amid stubborn inflation concerns; STI down 0.3%', 'events': []}]
# [{'text': "Aging Uruguay's vote to drop pension age is rattling investors", 'events': []}]
# [{'text': "Japanese atomic bomb survivors' group wins Nobel Peace Prize", 'events': [{'type': 'elect', 'trigger': 'wins', 'offset': [38, 42]}]}]
# [{'text': "Blinken condemns China's 'increasingly dangerous' sea moves", 'events': []}]
# [{'text': 'Former Louis Vuitton and Prada executive drafted in to revive Gucci', 'events': [{'type': 'endposition', 'trigger': 'Former', 'offset': [0, 6]}]}]
# [{'text': 'Joint study on regional energy connectivity by US, Singapore can guide framework for ASEAN power grid: PM Wong', 'events': []}]
# [{'text': 'What baseball star Shohei Ohtani’s success says about Japan', 'events': []}]
# [{'text': 'Socceroos have ‘nothing to fear’ from Japan', 'events': []}]
# [{'text': 'MAS to keep support for strong Singapore dollar amid rising inflation risks: Analysts', 'events': []}]
# [{'text': '‘I treat my pet like my child’: More in China travel with their furkids as pet industry booms', 'events': [{'type': 'transport', 'trigger': 'travel', 'offset': [46, 52]}]}]
# [{'text': 'Disinformation stirred by Musk and Trump adds strain to hurricane recovery in the US', 'events': [{'type': 'attack', 'trigger': 'hurricane', 'offset': [56, 65]}]}]
# [{'text': 'Commentary: US vice presidential nominee JD Vance articulates Trump’s policies better than Trump himself', 'events': [{'type': 'nominate', 'trigger': 'nominee', 'offset': [33, 40]}]}]
# [{'text': "A legacy in the making: Singapore's Banyan Group celebrates 30th anniversary", 'events': []}]
# [{'text': 'Silver says he expects NBA games will return to China after controversy', 'events': []}]
# [{'text': 'Asean bolsters ties with key partners in time of growing protectionism', 'events': []}]
# [{'text': 'Tomas Machac knocks world No. 2 Carlos Alcaraz out of Shanghai Masters', 'events': []}]
# [{'text': 'Beijing accuses Taiwan President Lai Ching-te of undermining peace in Taiwan Strait', 'events': [{'type': 'chargeindict', 'trigger': 'accuses', 'offset': [8, 15]}]}]
# [{'text': 'Asian Insider: Hamas attack on Israel one year on | Next lap of Asean-South Korea ties', 'events': [{'type': 'attack', 'trigger': 'attack', 'offset': [21, 27]}]}]
# [{'text': 'Asean and China take steps to upgrade free trade agreement, covering digital and green economies', 'events': []}]
# [{'text': 'A small US town is putting a spotlight on Chinese investment in America', 'events': []}]
# [{'text': '‘Ideas, industries, governance models’: Chan Chun Sing on how Suzhou Industrial Park helps China connect with the world', 'events': []}]
# [{'text': "‘More relevant than ever’: Suzhou Industrial Park signals China's global links amid troubled geopolitics, says Singapore", 'events': []}]
# [{'text': 'Philippines calls for urgency from China, ASEAN in negotiating South China Sea code', 'events': []}]
# [{'text': "China says Taiwan's leader 'hell bent' on independence", 'events': []}]
# [{'text': 'China to end Australia lobster sanctions, ending spiky spat', 'events': []}]
# [{'text': 'Upgrade to ASEAN-China free trade agreement almost completed, important in time of growing protectionism: PM Wong', 'events': []}]
# [{'text': 'Xi’s graft crackdown ensnares record number of senior officials in China', 'events': [{'type': 'attack', 'trigger': 'crackdown', 'offset': [11, 20]}]}]
# [{'text': 'US and allies’ trade coalition isolates China, ambassador says', 'events': []}]
# [{'text': 'China’s solar goes from supremacy to oversupply', 'events': []}]
# [{'text': 'Taiwan President Lai vows to ‘resist annexation’ of island', 'events': []}]
# [{'text': "Taiwan President Lai vows to 'resist annexation' of island", 'events': []}]
# [{'text': 'China central bank kicks off 500 billion yuan swap facility to aid stock market', 'events': []}]
# [{'text': '18-year-old Sherpa youngest to scale world’s 14 tallest peaks', 'events': []}]
# [{'text': 'OpenAI sees continued attempts by threat actors to use its models for election influence', 'events': [{'type': 'elect', 'trigger': 'election', 'offset': [70, 78]}]}]
# [{'text': 'Asian Insider: Hamas attack on Israel one year on | Next lap of Asean-South Korea ties', 'events': [{'type': 'attack', 'trigger': 'attack', 'offset': [21, 27]}]}]
# [{'text': 'Commentary: US not walking the talk in Southeast Asia as Biden skips ASEAN Summit again', 'events': [{'type': 'meet', 'trigger': 'Summit', 'offset': [75, 81]}]}]
# [{'text': 'Malaysia’s ASEAN chairmanship in 2025 could test bloc’s unity and ties with China', 'events': []}]
# [{'text': 'What will Malaysia push for as next ASEAN chair and could it affect grouping’s unity?', 'events': []}]
# [{'text': 'Equities gain after Fed minutes, inflation data and earnings in focus', 'events': []}]
# [{'text': 'Asean unity tested by its response to internal and regional challenges: PM Wong', 'events': []}]
# [{'text': 'Jannik Sinner to face Daniil Medvedev in Shanghai Masters quarter-finals', 'events': [{'type': 'meet', 'trigger': 'face', 'offset': [17, 21]}]}]
# [{'text': 'ASEAN must grow with less emissions, look to external partners to finance regional power grid: PM Wong', 'events': []}]
# [{'text': 'China’s Finance Minister to hold briefing on Oct 12 firing up hopes for big stimulus', 'events': [{'type': 'meet', 'trigger': 'briefing', 'offset': [33, 41]}]}]
# [{'text': 'Most Taiwanese believe China unlikely to invade in coming five years,\xa0poll\xa0shows', 'events': [{'type': 'attack', 'trigger': 'invade', 'offset': [41, 47]}]}]
# [{'text': 'Temu unlikely to give up on entering Indonesia despite continued rejection from the authorities', 'events': [{'type': 'transport', 'trigger': 'entering', 'offset': [28, 36]}]}]
# [{'text': 'Most Taiwanese believe China unlikely to invade in coming 5 years, poll shows', 'events': [{'type': 'attack', 'trigger': 'invade', 'offset': [41, 47]}]}]
# [{'text': 'As cassettes come back, the dilemma is finding a tape deck', 'events': []}]
# [{'text': 'Asean summit to seek progress on Myanmar civil war', 'events': [{'type': 'meet', 'trigger': 'summit', 'offset': [6, 12]}, {'type': 'attack', 'trigger': 'war', 'offset': [47, 50]}]}]
# [{'text': 'China says it raised ‘serious concerns’ with US over trade curbs', 'events': []}]
# [{'text': 'Commentary: The false promise of regime change in Iran', 'events': []}]
# [{'text': 'The world’s biggest indoor ski resort is in Shanghai, China', 'events': []}]
# [{'text': 'Sharing of trade, logistics data will help S. Korea, S’pore boost supply chain resilience: President Yoon', 'events': []}]
# [{'text': 'Asia’s high-net-worth market to grow by double digits in short term, say insurance firms', 'events': []}]
# [{'text': "China's Golden Week travel surges but spending lags pre-pandemic numbers", 'events': [{'type': 'transfermoney', 'trigger': 'spending', 'offset': [38, 46]}]}]
# [{'text': 'PM Wong to attend Asean meetings, visit Laos from Oct 9-12', 'events': [{'type': 'meet', 'trigger': 'meetings', 'offset': [24, 32]}, {'type': 'transport', 'trigger': 'visit', 'offset': [34, 39]}]}]
# [{'text': '‘More substantial cooperation’: S’pore, S. Korea to work towards upgrading ties to strategic partnership', 'events': []}]
# [{'text': 'China targets brandy in EU trade tit-for-tat after EV tariff move', 'events': []}]
# [{'text': 'China to take anti-dumping measures against EU brandy imports', 'events': []}]
# [{'text': 'UN biodiversity summit in Colombia aims to turn words into action', 'events': [{'type': 'meet', 'trigger': 'summit', 'offset': [16, 22]}]}]
# [{'text': "China's Pacific ally Kiribati criticises Beijing missile launch", 'events': []}]
# [{'text': 'China’s e-payment systems WeChat, Alipay dominate its cashless society. Can they repeat their success in Southeast Asia?', 'events': []}]
# [{'text': 'Singaporean singer Tanya Chua wins award for best original song at South Korean awards show', 'events': []}]
# [{'text': 'Commentary: Can China’s stimulus blitz fix its flagging economy?', 'events': []}]
# [{'text': 'Maldives President reverses anti-India course as Modi extends aid to ease debt worries', 'events': []}]
# [{'text': 'Forum: US and China must do more to compete and not fight', 'events': [{'type': 'attack', 'trigger': 'fight', 'offset': [52, 57]}]}]
# [{'text': 'Biden, Harris mark Oct 7 with call for Mideast peace', 'events': []}]
# [{'text': 'Next lap of Asean-South Korea ties to focus on tech, clean energy, says Yoon', 'events': []}]
# [{'text': 'Philippines launches naval drills with allies as regional tensions simmer', 'events': []}]
# [{'text': 'Taylor Fritz wins delayed match to reach Shanghai Masters third round', 'events': [{'type': 'elect', 'trigger': 'wins', 'offset': [13, 17]}]}]
# [{'text': 'S’pore aims to be a trusted, neutral hub for collaboration in global AI race: Chan Chun Sing', 'events': []}]
# [{'text': 'Tony Popovic’s ‘winning mentality’ can help Australia: Craig Goodwin', 'events': []}]
# [{'text': '‘Second family’: tennis stars hunt winning formula with new coaches', 'events': []}]
# [{'text': "China likely to launch military drills around Taiwan after president's national speech, sources say", 'events': [{'type': 'attack', 'trigger': 'drills', 'offset': [32, 38]}]}]

# %%
# get all from articles
ed_results = []
for row in tqdm(df.itertuples(index=False), total=len(df)):
    sentences = [s.strip() for s in row.Content.split(".")]
    ed_article = []
    for sentence in sentences:
        event = infer(text=sentence, task="ED", model=model, tokenizer=tokenizer)[0]
        if len(event['events']) > 0:
            ed_article.append(event)
    ed_results.append(ed_article)

# %%
df['ed_results'] = ed_results
df.to_parquet("../data/ed_output.parquet", engine="pyarrow")
